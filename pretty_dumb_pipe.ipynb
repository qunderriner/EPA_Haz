# %%
# %load_ext autoreload
# %autoreload 2
import pandas as pd
import numpy as np

# %%
import babypipe_3
# Out:
# /Users/quinnunderriner/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
# /Users/quinnunderriner/anaconda3/lib/python3.7/site-packages/sklearn/grid_search.py:14: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
#   from collections import Mapping, namedtuple, Sized
# /Users/quinnunderriner/anaconda3/lib/python3.7/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /Users/quinnunderriner/anaconda3/lib/python3.7/site-packages/sklearn/grid_search.py:42: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)

# %%
#load data
df = babypipe_3.load_data("RCRA_EVALUATIONS.csv")

# %%
#drop unique IDs
drop_list = ["ID_NUMBER"]

# %%
#do preprosessing 
df = babypipe_3.preprocess(df, drop_list)

# %%
#run me 4 definitions needed for model 

response = "predvar"

features = [x for x in df.columns if x not in [ 'EVALUATION_START_DATE', 'predvar', "FOUND_VIOLATION"]]

dummy_list = ["EVALUATION_AGENCY","EVALUATION_DESC","EVALUATION_TYPE","EVALUATION_IDENTIFIER","ACTIVITY_LOCATION"]
date_col = 'EVALUATION_START_DATE'
discrete_list = []
impute_median_list = []
impute_mean_list = []

# %%
df = babypipe_3.run_the_models(df, ['logistic_regression'], date_col, response, features, dummy_list, discrete_list, impute_median_list, impute_mean_list)
# Out:
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.001}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.01}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 10}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.001}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.01}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 10}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.001}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.01}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 10}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.001}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.01}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 10}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.001}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.01}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 10}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.001}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.01}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 10}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.001}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.01}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 10}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.001}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.01}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 10}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.001}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.01}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 10}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.001}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.01}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 10}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.001}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.01}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 10}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.001}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.01}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 10}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.001}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.01}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 10}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.001}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.01}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 10}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.001}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.01}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 10}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.001}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.01}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 10}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.001}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.01}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 10}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.001}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.01}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 10}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.001}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.01}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 10}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.001}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.01}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 10}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.001}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.01}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 10}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.001}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.01}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 10}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.001}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.01}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 10}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.001}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.01}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 10}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.001}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.01}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 10}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.001}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.01}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 10}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.001}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.01}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 10}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.001}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.01}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 10}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.001}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.01}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 10}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.001}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.01}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 10}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.001}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.01}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 10}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.001}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.01}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 10}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.001}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.01}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 10}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.001}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.01}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 10}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.001}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.01}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 10}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.001}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.01}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 10}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.001}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.01}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 10}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.001}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.01}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 10}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.001}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.01}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 10}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.001}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.01}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 10}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.001}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.01}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 10}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.001}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.01}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 10}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.001}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.01}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 10}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.001}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.01}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 10}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.001}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.01}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 10}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.001}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.01}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 10}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.001}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.01}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 10}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.001}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.01}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 10}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.001}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.01}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 10}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.001}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.01}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 10}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.001}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.01}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 10}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.001}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.01}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 0.1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 1}
# Input contains NaN, infinity or a value too large for dtype('float64'). logistic_regression {'C': 10}

# %%
df
# Out:
#                   model    parameters train_start  train_end test_start  \
# 0   logistic_regression  {'C': 0.001}  1990-01-01 1996-01-31 1996-03-31
# 1   logistic_regression   {'C': 0.01}  1990-01-01 1996-01-31 1996-03-31
# 2   logistic_regression    {'C': 0.1}  1990-01-01 1996-01-31 1996-03-31
# 3   logistic_regression      {'C': 1}  1990-01-01 1996-01-31 1996-03-31
# 4   logistic_regression     {'C': 10}  1990-01-01 1996-01-31 1996-03-31
# 5   logistic_regression  {'C': 0.001}  1990-01-01 1997-07-31 1997-09-29
# 6   logistic_regression   {'C': 0.01}  1990-01-01 1997-07-31 1997-09-29
# 7   logistic_regression    {'C': 0.1}  1990-01-01 1997-07-31 1997-09-29
# 8   logistic_regression      {'C': 1}  1990-01-01 1997-07-31 1997-09-29
# 9   logistic_regression     {'C': 10}  1990-01-01 1997-07-31 1997-09-29
# 10  logistic_regression  {'C': 0.001}  1990-01-01 1998-01-31 1998-04-01
# 11  logistic_regression   {'C': 0.01}  1990-01-01 1998-01-31 1998-04-01
# 12  logistic_regression    {'C': 0.1}  1990-01-01 1998-01-31 1998-04-01
# 13  logistic_regression      {'C': 1}  1990-01-01 1998-01-31 1998-04-01
# 14  logistic_regression     {'C': 10}  1990-01-01 1998-01-31 1998-04-01
# 15  logistic_regression  {'C': 0.001}  1990-01-01 2000-07-31 2000-09-29
# 16  logistic_regression   {'C': 0.01}  1990-01-01 2000-07-31 2000-09-29
# 17  logistic_regression    {'C': 0.1}  1990-01-01 2000-07-31 2000-09-29
# 18  logistic_regression      {'C': 1}  1990-01-01 2000-07-31 2000-09-29
# 19  logistic_regression     {'C': 10}  1990-01-01 2000-07-31 2000-09-29
# 20  logistic_regression  {'C': 0.001}  1990-01-01 2001-01-31 2001-04-01
#     recall_at_0.3  recall_at_0.5
# 0        0.917313       0.372193
# 1        0.889138       0.540833
# 2        0.850755       0.548795
# 3        0.850755       0.552879
# 4        0.850755       0.552879
# 5        0.895956       0.244945
# 6        0.841828       0.291070
# 7        0.841196       0.420177
# 8        0.890059       0.433235
# 9        0.890059       0.433235
# 10       0.899293       0.274703
# 11       0.892050       0.337989
# 12       0.891361       0.420935
# 13       0.891361       0.420935
# 14       0.891361       0.420935
# 15       0.906257       0.273087
# 16       0.903233       0.290067
# 17       0.906955       0.290998
# 18       0.906955       0.290998
# 19       0.906955       0.290998
# 20       0.868147       0.265519
# 21       0.855913       0.283416
# 22       0.862710       0.286135
# 23       0.874717       0.289760
# 24       0.874717       0.289760
# 25       0.856431       0.231372
# 26       0.817276       0.242762
# 27       0.807072       0.248695
# 28       0.807072       0.248695
# 29       0.807072       0.248695
#
# [30 rows x 22 columns]

# %%
    thresholds = [0.01, 0.02, 0.05, 0.10, 0.20, 0.30, 0.50]
    precision_cols = ["precision_at_{}".format(str(x)) for x in thresholds]
    recall_cols = ["recall_at_{}".format(str(x)) for x in thresholds]
    cols = ['model',
            'parameters',
            'train_start',
            'train_end',
            'test_start',
            'test_end',
            'f1_score',
            'auc'] + precision_cols + recall_cols
    model_results = []
    # feature selection
    processed_data = babypipe_3.process(df, dummy_list, discrete_list, impute_median_list, impute_mean_list)
    features = [x for x in processed_data.columns if x not in ID_COLS]
    features = babypipe_3.choose_features(processed_data, response, features)

# %%
ID_COLS = [
'EVALUATION_START_DATE', 'predvar', "FOUND_VIOLATION"]

# %%
splits = babypipe_3.temporal_train_test_split(df, date_col, freq='6M')

# %%
features = [x for x in df.columns if x not in ['predvar']]

# %%
for train, test in splits:
    train_df, test_df = babypipe_3.split_df_by_time(df, date_col, train, test)
    train_df = babypipe_3.process(train_df, dummy_list, discrete_list, impute_median_list, impute_mean_list)
    test_df = babypipe_3.process(test_df, dummy_list, discrete_list, impute_median_list, impute_mean_list)
    X_train, y_train = babypipe_3.get_xy(train_df, response, features)
    X_test, y_test = babypipe_3.get_xy(test_df, response, features)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-bd62592e7260> in <module>()
#       3     train_df = babypipe_3.process(train_df, dummy_list, discrete_list, impute_median_list, impute_mean_list)
#       4     test_df = babypipe_3.process(test_df, dummy_list, discrete_list, impute_median_list, impute_mean_list)
# ----> 5     X_train, y_train = babypipe_3.get_xy(train_df, response, features)
#       6     X_test, y_test = babypipe_3.get_xy(test_df, response, features)
#       7
#
# ~/Desktop/school/Machine_Learning/rcra_downloads/babypipe_3.py in get_xy(df, response, features)
#     150     y = df[response].to_numpy()
#     151     #df = df.reindex(columns=columns)
# --> 152     X = df[features].to_numpy()
#     153     return X, y
#     154
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2932                 key = list(key)
#    2933             indexer = self.loc._convert_to_indexer(key, axis=1,
# -> 2934                                                    raise_missing=True)
#    2935
#    2936         # take() does not accept boolean indexers
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1352                 kwargs = {'raise_missing': True if is_setter else
#    1353                           raise_missing}
# -> 1354                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
#    1355         else:
#    1356             try:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1159         self._validate_read_indexer(keyarr, indexer,
#    1160                                     o._get_axis_number(axis),
# -> 1161                                     raise_missing=raise_missing)
#    1162         return keyarr, indexer
#    1163
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1250             if not(self.name == 'loc' and not raise_missing):
#    1251                 not_found = list(set(key) - set(ax))
# -> 1252                 raise KeyError("{} not in index".format(not_found))
#    1253
#    1254             # we skip the warning on Categorical/Interval
#
# KeyError: "['EVALUATION_DESC_COMPLIANCE ASSISTANCE VISIT', 'EVALUATION_TYPE_CAV', 'ACTIVITY_LOCATION_WA', 'EVALUATION_TYPE_FSD'] not in index"
